# %% [markdown]
# Experiment Xception

# %% [markdown]
# **GPU, Epochs Number, Batch Size, Learing Rate**

# %%
# !nvidia-smi -q -i 0 | grep "Product Name"
# Out:
#     Product Name                          : Tesla P100-PCIE-16GB

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Jul 27 07:43:55 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    31W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
#!pip install -q tensorflow-gpu==2.9.0
# %tensorflow_version 2.x
import tensorflow as tf

# %%
try: # detect TPUs
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect() # TPU detection
    strategy = tf.distribute.TPUStrategy(tpu)
except ValueError: # detect GPUs
    strategy = tf.distribute.MirroredStrategy() # for GPU or multi-GPU machines
print("Number of accelerators: ", strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of accelerators:  1

# %% [markdown]
# Mixed precision

# %%
# mixed precision
MIXED_PRECISION = False # Tesla P100-PCIE-16GB, compute capability 6.0: does not support permomance improvements for mux precisions
if MIXED_PRECISION:
  policy = tf.keras.mixed_precision.Policy('mixed_float16')
  tf.config.optimizer.set_jit(True) # XLA compilation
  tf.keras.mixed_precision.set_global_policy(policy)
  print('Mixed precision enabled')

print('Compute dtype: %s' % policy.compute_dtype)
print('Variable dtype: %s' % policy.variable_dtype)
# Out:
# Compute dtype: float16
# Variable dtype: float32

# %% [markdown]
# Batch size and learning rate

# %%
from matplotlib import pyplot as plt

BATCH_SIZE = 64 # 128 works on GPU too but comes very close to the memory limit of the Colab GPU
EPOCHS = 50

print('strategy.num_replicas_in_sync: ', strategy.num_replicas_in_sync)

# batch and learning rate settings
if strategy.num_replicas_in_sync == 8: # TPU or 8xGPU
    BATCH_SIZE = 16 * strategy.num_replicas_in_sync
    VALIDATION_BATCH_SIZE = 16 * strategy.num_replicas_in_sync
    start_lr = 0.00001
    min_lr = 0.00001
    max_lr = 0.00005 * strategy.num_replicas_in_sync
    rampup_epochs = 5
    sustain_epochs = 0
    exp_decay = .8
elif strategy.num_replicas_in_sync == 1: # single GPU
    BATCH_SIZE = 16
    VALIDATION_BATCH_SIZE = 16
    start_lr = 0.00001
    min_lr = 0.00001
    max_lr = 0.0002
    rampup_epochs = 5
    sustain_epochs = 0
    exp_decay = .8
else: # TPU pod
    BATCH_SIZE = 8 * strategy.num_replicas_in_sync
    VALIDATION_BATCH_SIZE = 8 * strategy.num_replicas_in_sync
    start_lr = 0.00001
    min_lr = 0.00001
    max_lr = 0.00002 * strategy.num_replicas_in_sync
    rampup_epochs = 7
    sustain_epochs = 0
    exp_decay = .8

def lrfn(epoch):
    def lr(epoch, start_lr, min_lr, max_lr, rampup_epochs, sustain_epochs, exp_decay):
        if epoch < rampup_epochs:
            lr = (max_lr - start_lr)/rampup_epochs * epoch + start_lr
        elif epoch < rampup_epochs + sustain_epochs:
            lr = max_lr
        else:
            lr = (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr
        return lr
    return lr(epoch, start_lr, min_lr, max_lr, rampup_epochs, sustain_epochs, exp_decay)
    
jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034039.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034040.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034041.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034042.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034043.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034044.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034045.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034047.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034053.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034054.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034055.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034056.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034057.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034058.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034060.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034063.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034066.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034067.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034069.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034070.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034072.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034073.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034075.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034077.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034078.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034079.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034080.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034081.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034082.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034083.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034084.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034086.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034088.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034090.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034091.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034093.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034095.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034096.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034097.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034098.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034099.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034102.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034103.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034105.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034108.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034109.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034110.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034111.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034112.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034113.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034114.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034115.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034116.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034119.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034121.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034122.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034123.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034124.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034125.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034126.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034127.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034128.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034129.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034130.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034131.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034133.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034135.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034136.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034137.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034138.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034139.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034142.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034143.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034144.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034146.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034147.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034148.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034149.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034151.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034152.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034153.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034154.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034155.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034156.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034157.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034158.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034160.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034161.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034163.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034164.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034165.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034166.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034167.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034168.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034169.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034171.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034174.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034175.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034176.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034177.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034178.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034179.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034181.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034182.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034184.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034185.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034186.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034187.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034189.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034190.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034191.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034192.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034193.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034194.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034195.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034196.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034197.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034198.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034199.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034200.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034201.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034203.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034204.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034206.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034207.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034209.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034210.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034212.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034213.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034214.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034215.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034217.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034219.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034220.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034221.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034223.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034224.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034225.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034226.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034227.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034228.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034229.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034230.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034231.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034232.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034234.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034235.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034237.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034238.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034240.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034241.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034244.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034245.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034247.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034248.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034249.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034250.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034251.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034252.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034254.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034255.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034257.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034258.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034259.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034260.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034261.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034264.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034265.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034266.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034267.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034268.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034270.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034271.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034272.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034273.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034274.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034276.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034277.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034278.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034279.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034280.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034281.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034282.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034283.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034285.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034286.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034288.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034290.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034291.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034292.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034293.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034295.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034296.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034297.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034298.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034299.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034300.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034301.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034302.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034303.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034304.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034305.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034306.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034307.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034308.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034309.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034310.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034311.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034312.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034314.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034315.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034318.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034319.jpg
#   inflating: melanoma/NotMelanoma/ISIC_0034320.jpg

# %%
import os

print(len(os.listdir('melanoma/Melanoma')))
print(len(os.listdir('melanoma/NotMelanoma')))
# Out:
# 8903
# 8902

# %%
from shutil import copyfile
import random

try:
    os.mkdir('training')
    os.mkdir('validation')
    os.mkdir('testing')
    os.mkdir('training/Melanoma')
    os.mkdir('training/NotMelanoma')
    os.mkdir('validation/Melanoma')
    os.mkdir('validation/NotMelanoma')
    os.mkdir('testing/Melanoma')
    os.mkdir('testing/NotMelanoma')
except OSError:
    pass

def split_data(SOURCE, TRAINING, VALIDATION, TESTING, SPLIT_SIZE):
    files = []
    for filename in os.listdir(SOURCE):
        file = SOURCE + filename
        if os.path.getsize(file) > 0:
            files.append(filename)
        else:
            print(filename + " is zero length, so ignoring.")
 

    dataset_length = len(files)
    validation_length = int(dataset_length * SPLIT_SIZE)
    testing_length = int(dataset_length * SPLIT_SIZE)
    training_length = dataset_length - (testing_length + validation_length)
    
    shuffled_set = random.sample(files, dataset_length)

    training_set = shuffled_set[0:training_length]
    testing_set = shuffled_set[training_length:training_length + testing_length]
    validation_set = shuffled_set[training_length+testing_length:dataset_length]
 
    for filename in training_set:
        this_file = SOURCE + filename
        destination = TRAINING + filename
        copyfile(this_file, destination)
 
    for filename in testing_set:
        this_file = SOURCE + filename
        destination = TESTING + filename
        copyfile(this_file, destination)
    
    for filename in validation_set:
        this_file = SOURCE + filename
        destination = VALIDATION + filename
        copyfile(this_file, destination)
 
 
MELANOMA_SOURCE_DIR = "melanoma/Melanoma/"
NOT_MELANOMA_SOURCE_DIR = "melanoma/NotMelanoma/"

TRAINING_MELANOMA_DIR = "training/Melanoma/"
TRAINING_NOT_MELANOMA_DIR = "training/NotMelanoma/"

VALIDATION_MELANOMA_DIR = "validation/Melanoma/"
VALIDATION_NOT_MELANOMA_DIR = "validation/NotMelanoma/"

TESTING_MELANOMA_DIR = "testing/Melanoma/"
TESTING_NOT_MELANOMA_DIR = "testing/NotMelanoma/"

 
validation_split = 0.19
split_data(MELANOMA_SOURCE_DIR, TRAINING_MELANOMA_DIR, VALIDATION_MELANOMA_DIR, TESTING_MELANOMA_DIR, validation_split)
split_data(NOT_MELANOMA_SOURCE_DIR, TRAINING_NOT_MELANOMA_DIR, VALIDATION_NOT_MELANOMA_DIR, TESTING_NOT_MELANOMA_DIR, validation_split)

# %%
print(len(os.listdir('training/Melanoma/')))
print(len(os.listdir('training/NotMelanoma/')))
print(len(os.listdir('validation/Melanoma/')))
print(len(os.listdir('validation/NotMelanoma/')))
print(len(os.listdir('testing/Melanoma/')))
print(len(os.listdir('testing/NotMelanoma/')))

training_data_amount = len(os.listdir('training/Melanoma/')) + len(os.listdir('training/NotMelanoma/'))
validation_data_amount = len(os.listdir('validation/Melanoma/')) + len(os.listdir('validation/NotMelanoma/'))
testing_data_amount = len(os.listdir('testing/Melanoma/')) + len(os.listdir('testing/NotMelanoma/'))

TRAIN_STEPS = training_data_amount // BATCH_SIZE
VALIDATION_STEPS = validation_data_amount // BATCH_SIZE
TEST_STEPS = testing_data_amount // BATCH_SIZE

print("BATCH SIZE: ", BATCH_SIZE)

print("TRAINING IMAGES: ", training_data_amount)
print("VALIDATION IMAGES: ", validation_data_amount)
print("TESTING IMAGES: ", testing_data_amount)

print("TRAIN STEPS: ", TRAIN_STEPS)
print("VALIDATION STEPS: ", VALIDATION_STEPS)
print("TEST STEPS: ", TEST_STEPS)
# Out:
# 5521
# 5520
# 1691
# 1691
# 1691
# 1691
# BATCH SIZE:  16
# TRAINING IMAGES:  11041
# VALIDATION IMAGES:  3382
# TESTING IMAGES:  3382
# TRAIN STEPS:  690
# VALIDATION STEPS:  211
# TEST STEPS:  211

# %%
# model = "xception"
# NUM_CLASSES = 2 : {'Melanoma': 0, 'NotMelanoma': 1}
# The size of images in the dataset is 600x450x3 
# Input Shape: [299, 299, 3]

INPUT_SHAPE = (299, 299)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255.)
validation_datagen = ImageDataGenerator(rescale=1./255.)
test_datagen = ImageDataGenerator(rescale=1./255.)

TRAINING_DIR = "training/"
train_generator = train_datagen.flow_from_directory(
                      TRAINING_DIR,
                       batch_size=BATCH_SIZE,
                       class_mode='binary',
                       target_size=INPUT_SHAPE)

VALIDATION_DIR = "validation/"
validation_generator = validation_datagen.flow_from_directory(
                       VALIDATION_DIR,
                       batch_size=BATCH_SIZE,
                       class_mode='binary',
                       target_size=INPUT_SHAPE)

TESTING_DIR = "testing/"
test_generator = test_datagen.flow_from_directory(
                      TESTING_DIR,
                       batch_size=BATCH_SIZE,
                       class_mode='binary',
                       target_size=INPUT_SHAPE)
# Out:
# Found 11041 images belonging to 2 classes.
# Found 3382 images belonging to 2 classes.
# Found 3382 images belonging to 2 classes.

# %%
print(train_generator.class_indices)
print(validation_generator.class_indices)
print(test_generator.class_indices)
# Out:
# {'Melanoma': 0, 'NotMelanoma': 1}
# {'Melanoma': 0, 'NotMelanoma': 1}
# {'Melanoma': 0, 'NotMelanoma': 1}

# %%
from tensorflow.keras import layers
from tensorflow.keras import regularizers

def create_Xception_base():
  xception_base = tf.keras.applications.xception.Xception(
      weights='imagenet', # Load weights pre-trained on ImageNet.
      include_top=False, # Do not include the ImageNet classifier at the top.
      input_shape=[*INPUT_SHAPE, 3])
  
  #freeze base model
  xception_base.trainable = False

  return xception_base

def create_Xception_model():
  modelXception = tf.keras.Sequential([
      create_Xception_base(),
      layers.GlobalAveragePooling2D(),
      layers.Dropout(0.2),
      layers.Dense(64, activation ='relu',kernel_regularizer = regularizers.l2(0.001)),
      layers.Dropout(0.2),
      layers.Dense(1, activation ='sigmoid')
    ])
    
  modelXception.compile(
      optimizer = tf.keras.optimizers.Adam(),
      loss = tf.keras.losses.BinaryCrossentropy(from_logits=True),
      metrics = [tf.keras.metrics.BinaryAccuracy()]
    )
  
  return modelXception


with strategy.scope(): # creating the model in the TPUStrategy scope places the model on the TPU
  modelXception = create_Xception_model()
  
modelXception.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  global_average_pooling2d_21  (None, 2048)             0
#   (GlobalAveragePooling2D)
#
#  dropout_31 (Dropout)        (None, 2048)              0
#
#  dense_34 (Dense)            (None, 64)                131136
#
#  dropout_32 (Dropout)        (None, 64)                0
#
#  dense_35 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 20,992,681
# Trainable params: 131,201
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
import time
import numpy as np

start_time = time.time()

history = modelXception.fit(train_generator,
                            epochs = EPOCHS,
                            verbose = 1,
                            callbacks = [lr_callback],
                            validation_data = validation_generator,
                            steps_per_epoch = TRAIN_STEPS)

end_date = time.time()

final_accuracy = history.history["val_binary_accuracy"][-5:]
print("FINAL ACCURACY MEAN-5: ", np.mean(final_accuracy))
print("TRAINING TIME: ", end_date - start_time, " sec")
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 1e-05.
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 690/690 [==============================] - 114s 149ms/step - loss: 0.7283 - binary_accuracy: 0.7185 - val_loss: 0.6097 - val_binary_accuracy: 0.8906 - lr: 1.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 4.8e-05.
# Epoch 2/50
# 690/690 [==============================] - 100s 144ms/step - loss: 0.4345 - binary_accuracy: 0.9076 - val_loss: 0.3459 - val_binary_accuracy: 0.9187 - lr: 4.8000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 8.6e-05.
# Epoch 3/50
# 690/690 [==============================] - 96s 140ms/step - loss: 0.3276 - binary_accuracy: 0.9238 - val_loss: 0.3031 - val_binary_accuracy: 0.9311 - lr: 8.6000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.000124.
# Epoch 4/50
# 690/690 [==============================] - 96s 140ms/step - loss: 0.2854 - binary_accuracy: 0.9273 - val_loss: 0.2762 - val_binary_accuracy: 0.9326 - lr: 1.2400e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.000162.
# Epoch 5/50
# 690/690 [==============================] - 96s 138ms/step - loss: 0.2570 - binary_accuracy: 0.9307 - val_loss: 0.2475 - val_binary_accuracy: 0.9281 - lr: 1.6200e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0002.
# Epoch 6/50
# 690/690 [==============================] - 95s 138ms/step - loss: 0.2366 - binary_accuracy: 0.9347 - val_loss: 0.2333 - val_binary_accuracy: 0.9338 - lr: 2.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.000162.
# Epoch 7/50
# 690/690 [==============================] - 95s 138ms/step - loss: 0.2204 - binary_accuracy: 0.9365 - val_loss: 0.2275 - val_binary_accuracy: 0.9332 - lr: 1.6200e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.00013160000000000003.
# Epoch 8/50
# 690/690 [==============================] - 96s 139ms/step - loss: 0.2105 - binary_accuracy: 0.9369 - val_loss: 0.2149 - val_binary_accuracy: 0.9361 - lr: 1.3160e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.00010728000000000003.
# Epoch 9/50
# 690/690 [==============================] - 96s 140ms/step - loss: 0.2028 - binary_accuracy: 0.9381 - val_loss: 0.2097 - val_binary_accuracy: 0.9352 - lr: 1.0728e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 8.782400000000002e-05.
# Epoch 10/50
# 690/690 [==============================] - 95s 138ms/step - loss: 0.1967 - binary_accuracy: 0.9393 - val_loss: 0.2043 - val_binary_accuracy: 0.9352 - lr: 8.7824e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 7.225920000000001e-05.
# Epoch 11/50
# 690/690 [==============================] - 95s 137ms/step - loss: 0.1912 - binary_accuracy: 0.9411 - val_loss: 0.2023 - val_binary_accuracy: 0.9370 - lr: 7.2259e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 5.9807360000000024e-05.
# Epoch 12/50
# 690/690 [==============================] - 95s 137ms/step - loss: 0.1893 - binary_accuracy: 0.9406 - val_loss: 0.2011 - val_binary_accuracy: 0.9347 - lr: 5.9807e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.984588800000002e-05.
# Epoch 13/50
# 690/690 [==============================] - 96s 138ms/step - loss: 0.1865 - binary_accuracy: 0.9418 - val_loss: 0.1995 - val_binary_accuracy: 0.9352 - lr: 4.9846e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.187671040000002e-05.
# Epoch 14/50
# 690/690 [==============================] - 95s 137ms/step - loss: 0.1841 - binary_accuracy: 0.9418 - val_loss: 0.1970 - val_binary_accuracy: 0.9370 - lr: 4.1877e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 3.550136832000001e-05.
# Epoch 15/50
# 690/690 [==============================] - 94s 136ms/step - loss: 0.1828 - binary_accuracy: 0.9424 - val_loss: 0.1961 - val_binary_accuracy: 0.9367 - lr: 3.5501e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 3.0401094656000014e-05.
# Epoch 16/50
# 690/690 [==============================] - 94s 136ms/step - loss: 0.1793 - binary_accuracy: 0.9435 - val_loss: 0.1987 - val_binary_accuracy: 0.9332 - lr: 3.0401e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 2.6320875724800014e-05.
# Epoch 17/50
# 690/690 [==============================] - 94s 137ms/step - loss: 0.1788 - binary_accuracy: 0.9429 - val_loss: 0.1946 - val_binary_accuracy: 0.9370 - lr: 2.6321e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 2.3056700579840008e-05.
# Epoch 18/50
# 690/690 [==============================] - 93s 135ms/step - loss: 0.1794 - binary_accuracy: 0.9442 - val_loss: 0.1943 - val_binary_accuracy: 0.9361 - lr: 2.3057e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 2.0445360463872006e-05.
# Epoch 19/50
# 690/690 [==============================] - 94s 136ms/step - loss: 0.1764 - binary_accuracy: 0.9437 - val_loss: 0.1946 - val_binary_accuracy: 0.9361 - lr: 2.0445e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 1.835628837109761e-05.
# Epoch 20/50
# 690/690 [==============================] - 94s 136ms/step - loss: 0.1750 - binary_accuracy: 0.9449 - val_loss: 0.1958 - val_binary_accuracy: 0.9347 - lr: 1.8356e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 1.6685030696878088e-05.
# Epoch 21/50
# 690/690 [==============================] - 94s 136ms/step - loss: 0.1756 - binary_accuracy: 0.9429 - val_loss: 0.1936 - val_binary_accuracy: 0.9364 - lr: 1.6685e-05
#
# Epoch 22: LearningRateScheduler setting learning rate to 1.534802455750247e-05.
# Epoch 22/50
# 690/690 [==============================] - 94s 137ms/step - loss: 0.1758 - binary_accuracy: 0.9431 - val_loss: 0.1929 - val_binary_accuracy: 0.9367 - lr: 1.5348e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 1.4278419646001977e-05.
# Epoch 23/50
# 690/690 [==============================] - 94s 137ms/step - loss: 0.1752 - binary_accuracy: 0.9428 - val_loss: 0.1923 - val_binary_accuracy: 0.9367 - lr: 1.4278e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 1.3422735716801581e-05.
# Epoch 24/50
# 690/690 [==============================] - 94s 136ms/step - loss: 0.1750 - binary_accuracy: 0.9437 - val_loss: 0.1930 - val_binary_accuracy: 0.9355 - lr: 1.3423e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 1.2738188573441265e-05.
# Epoch 25/50
# 690/690 [==============================] - 95s 137ms/step - loss: 0.1757 - binary_accuracy: 0.9431 - val_loss: 0.1920 - val_binary_accuracy: 0.9364 - lr: 1.2738e-05
#
# Epoch 26: LearningRateScheduler setting learning rate to 1.2190550858753013e-05.
# Epoch 26/50
# 690/690 [==============================] - 94s 137ms/step - loss: 0.1754 - binary_accuracy: 0.9429 - val_loss: 0.1917 - val_binary_accuracy: 0.9361 - lr: 1.2191e-05
#
# Epoch 27: LearningRateScheduler setting learning rate to 1.175244068700241e-05.
# Epoch 27/50
# 690/690 [==============================] - 95s 137ms/step - loss: 0.1741 - binary_accuracy: 0.9449 - val_loss: 0.1925 - val_binary_accuracy: 0.9370 - lr: 1.1752e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 1.1401952549601928e-05.
# Epoch 28/50
# 690/690 [==============================] - 94s 136ms/step - loss: 0.1732 - binary_accuracy: 0.9440 - val_loss: 0.1911 - val_binary_accuracy: 0.9370 - lr: 1.1402e-05
#
# Epoch 29: LearningRateScheduler setting learning rate to 1.1121562039681543e-05.
# Epoch 29/50
# 690/690 [==============================] - 94s 136ms/step - loss: 0.1720 - binary_accuracy: 0.9452 - val_loss: 0.1901 - val_binary_accuracy: 0.9373 - lr: 1.1122e-05
#
# Epoch 30: LearningRateScheduler setting learning rate to 1.0897249631745235e-05.
# Epoch 30/50
# 690/690 [==============================] - 94s 136ms/step - loss: 0.1715 - binary_accuracy: 0.9461 - val_loss: 0.1910 - val_binary_accuracy: 0.9361 - lr: 1.0897e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 1.0717799705396187e-05.
# Epoch 31/50
# 690/690 [==============================] - 93s 134ms/step - loss: 0.1722 - binary_accuracy: 0.9453 - val_loss: 0.1912 - val_binary_accuracy: 0.9358 - lr: 1.0718e-05
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.057423976431695e-05.
# Epoch 32/50
# 690/690 [==============================] - 93s 135ms/step - loss: 0.1709 - binary_accuracy: 0.9440 - val_loss: 0.1914 - val_binary_accuracy: 0.9358 - lr: 1.0574e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 1.0459391811453561e-05.
# Epoch 33/50
# 690/690 [==============================] - 93s 135ms/step - loss: 0.1702 - binary_accuracy: 0.9458 - val_loss: 0.1913 - val_binary_accuracy: 0.9364 - lr: 1.0459e-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 1.0367513449162848e-05.
# Epoch 34/50
# 690/690 [==============================] - 92s 134ms/step - loss: 0.1676 - binary_accuracy: 0.9458 - val_loss: 0.1896 - val_binary_accuracy: 0.9361 - lr: 1.0368e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.0294010759330279e-05.
# Epoch 35/50
# 690/690 [==============================] - 93s 134ms/step - loss: 0.1685 - binary_accuracy: 0.9455 - val_loss: 0.1898 - val_binary_accuracy: 0.9358 - lr: 1.0294e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 1.0235208607464223e-05.
# Epoch 36/50
# 690/690 [==============================] - 94s 136ms/step - loss: 0.1699 - binary_accuracy: 0.9461 - val_loss: 0.1890 - val_binary_accuracy: 0.9364 - lr: 1.0235e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 1.018816688597138e-05.
# Epoch 37/50
# 690/690 [==============================] - 95s 137ms/step - loss: 0.1705 - binary_accuracy: 0.9457 - val_loss: 0.1891 - val_binary_accuracy: 0.9358 - lr: 1.0188e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.0150533508777103e-05.
# Epoch 38/50
# 690/690 [==============================] - 95s 137ms/step - loss: 0.1688 - binary_accuracy: 0.9464 - val_loss: 0.1896 - val_binary_accuracy: 0.9358 - lr: 1.0151e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.0120426807021682e-05.
# Epoch 39/50
# 690/690 [==============================] - 95s 137ms/step - loss: 0.1666 - binary_accuracy: 0.9451 - val_loss: 0.1897 - val_binary_accuracy: 0.9358 - lr: 1.0120e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 1.0096341445617346e-05.
# Epoch 40/50
# 690/690 [==============================] - 95s 137ms/step - loss: 0.1694 - binary_accuracy: 0.9448 - val_loss: 0.1891 - val_binary_accuracy: 0.9361 - lr: 1.0096e-05
#
# Epoch 41: LearningRateScheduler setting learning rate to 1.0077073156493877e-05.
# Epoch 41/50
# 690/690 [==============================] - 92s 133ms/step - loss: 0.1688 - binary_accuracy: 0.9459 - val_loss: 0.1889 - val_binary_accuracy: 0.9361 - lr: 1.0077e-05
#
# Epoch 42: LearningRateScheduler setting learning rate to 1.0061658525195102e-05.
# Epoch 42/50
# 690/690 [==============================] - 90s 130ms/step - loss: 0.1663 - binary_accuracy: 0.9467 - val_loss: 0.1890 - val_binary_accuracy: 0.9358 - lr: 1.0062e-05
#
# Epoch 43: LearningRateScheduler setting learning rate to 1.0049326820156082e-05.
# Epoch 43/50
# 690/690 [==============================] - 89s 129ms/step - loss: 0.1667 - binary_accuracy: 0.9454 - val_loss: 0.1886 - val_binary_accuracy: 0.9358 - lr: 1.0049e-05
#
# Epoch 44: LearningRateScheduler setting learning rate to 1.0039461456124866e-05.
# Epoch 44/50
# 690/690 [==============================] - 90s 130ms/step - loss: 0.1657 - binary_accuracy: 0.9463 - val_loss: 0.1885 - val_binary_accuracy: 0.9358 - lr: 1.0039e-05
#
# Epoch 45: LearningRateScheduler setting learning rate to 1.0031569164899892e-05.
# Epoch 45/50
# 690/690 [==============================] - 91s 131ms/step - loss: 0.1655 - binary_accuracy: 0.9459 - val_loss: 0.1878 - val_binary_accuracy: 0.9358 - lr: 1.0032e-05
#
# Epoch 46: LearningRateScheduler setting learning rate to 1.0025255331919914e-05.
# Epoch 46/50
# 690/690 [==============================] - 91s 131ms/step - loss: 0.1686 - binary_accuracy: 0.9449 - val_loss: 0.1877 - val_binary_accuracy: 0.9358 - lr: 1.0025e-05
#
# Epoch 47: LearningRateScheduler setting learning rate to 1.0020204265535932e-05.
# Epoch 47/50
# 690/690 [==============================] - 91s 131ms/step - loss: 0.1674 - binary_accuracy: 0.9456 - val_loss: 0.1876 - val_binary_accuracy: 0.9367 - lr: 1.0020e-05
#
# Epoch 48: LearningRateScheduler setting learning rate to 1.0016163412428746e-05.
# Epoch 48/50
# 690/690 [==============================] - 90s 130ms/step - loss: 0.1674 - binary_accuracy: 0.9449 - val_loss: 0.1878 - val_binary_accuracy: 0.9364 - lr: 1.0016e-05
#
# Epoch 49: LearningRateScheduler setting learning rate to 1.0012930729942996e-05.
# Epoch 49/50
# 690/690 [==============================] - 90s 131ms/step - loss: 0.1670 - binary_accuracy: 0.9457 - val_loss: 0.1867 - val_binary_accuracy: 0.9376 - lr: 1.0013e-05
#
# Epoch 50: LearningRateScheduler setting learning rate to 1.0010344583954397e-05.
# Epoch 50/50
# 690/690 [==============================] - 89s 129ms/step - loss: 0.1651 - binary_accuracy: 0.9454 - val_loss: 0.1880 - val_binary_accuracy: 0.9361 - lr: 1.0010e-05
# FINAL ACCURACY MEAN-5:  0.9365464687347412
# TRAINING TIME:  4709.052837610245  sec

# %%
# We can save our model with:
modelXception.save('modelXceptionApproachA.h5')
# and reload it with:
reloaded_model = tf.keras.models.load_model('modelXceptionApproachA.h5')

# %%
test_loss, test_acc = modelXception.evaluate_generator(
    test_generator, 
    steps = TEST_STEPS, 
    verbose = 1)

print('test acc:', test_acc)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   after removing the cwd from sys.path.
# 211/211 [==============================] - 23s 106ms/step - loss: 0.1777 - binary_accuracy: 0.9422
# test acc: 0.9422393441200256

# %%
# %matplotlib inline
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['binary_accuracy']
val_acc=history.history['val_binary_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
 
epochs=range(len(acc)) # Get number of epochs
 
#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.figure()
 
 #------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.figure()

# %%
print(history.history.keys())

def display_training_curves(training, validation, title, subplot):
  if subplot%10==1: # set up the subplots on the first call
    plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
    #plt.tight_layout()
  ax = plt.subplot(subplot)
  ax.set_facecolor('#F8F8F8')
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('model '+ title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['train', 'valid.'])

display_training_curves(history.history['binary_accuracy'], history.history['val_binary_accuracy'], 'accuracy', 211)
display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 212)
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy', 'lr'])

# %% [markdown]
# Confusion Matrix

# %%
con_mat = tf.math.confusion_matrix(labels=y_true, predictions=y_pred).numpy()
con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)

con_mat_df = pd.DataFrame(con_mat_norm,
                     index = classes, 
                     columns = classes)

figure = plt.figure(figsize=(8, 8))
sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
